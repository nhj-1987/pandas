# %%
import pandas as pd
import numpy as np
# %matplotlib inline

s= pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2015',periods=1000))
s.plot()

# %%
s = s.cumsum()
s.plot()

# %%
r = s.rolling(window=60)
# 이동평균 낼때
s.plot()
r.mean().plot(style='k')
