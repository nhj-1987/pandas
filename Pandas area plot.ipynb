# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df.head()
# Out:
#           a         b         c         d
# 0  0.082664  0.591058  0.864582  0.618342
# 1  0.750076  0.954765  0.762534  0.343564
# 2  0.556224  0.975330  0.620056  0.784316
# 3  0.863186  0.171032  0.006827  0.707576
# 4  0.004922  0.138239  0.725498  0.669727

# %%
 df.plot.area(stacked = False , grid =True) # stacked = 'true' default 누적
